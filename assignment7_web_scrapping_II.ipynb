# %% [markdown]
# <a href="https://colab.research.google.com/github/adong-hood/cs200/blob/main/assignment7_web_scrapping_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Web Scraping Practice II

# %% [markdown]
# The CIA website stopped publishing the world factbook in 2026 (<a href = "https://www.cia.gov/stories/story/spotlighting-the-world-factbook-as-we-bid-a-fond-farewell/">Spotlighting The World Factbook as We Bid a Fond Farewell
#  </a>). In this practice, we will use the snapshot of August 06, 2025 from the web archive. This page--[Guide to Country Profile](https://web.archive.org/web/20260204071503/https://www.cia.gov/the-world-factbook/countries/world/)--is very similar to the [Notes and Definitions](http://pluto.hood.edu/~dong/factbook-2017/docs/notesanddefs.html) page from the 2017 version.

# %% [markdown]
# To make the problem easier, we will let you start with this page directly: [Infant Mortality Rate](https://web.archive.org/web/20260204071503/https://www.cia.gov/the-world-factbook/field/infant-mortality-rate/) page directly.

# %% [markdown]
# **Your Task**
#
# Remember to share your notebook for any credits.
# <pre>
# Step 1: scrape the total infant mortality rates from 2024.
# Step 2: scrape the total infant mortality rates from 2017(assignment 6).
# Step 3: merge the infant mortality rates of 2017 with those of 2024. Find which country has the largest positive change from 2017 to 2024 and which country has the largest negative change during the same time period.
# </pre>

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 1. Scrape from the 2024 Archived CIA Website

# %%
#address = 'https://web.archive.org/web/20260204071503/https://www.cia.gov/the-world-factbook/field/infant-mortality-rate/'  # not reliable.
address_2024 = 'http://pluto.hood.edu/~dong/datasets/factbook/fields/infantmortality-2024.html' #- use this link instead.
res = requests.get(address_2024)
page_content_2024 = res.text

# %% [markdown]
# ### 2. Scrape from the 2017 pseudo-CIA Website (from assignment 6)

# %%
address_2017 = 'http://pluto.hood.edu/~dong/datasets/factbook/fields/2091.html#118'
res = requests.get(address_2017)
page_content_2017 = res.text

# %% [markdown]
# ### 3. Combine and sort the data. Find the countries with the largest positive change and which country has the largest negative change during the same time period.
